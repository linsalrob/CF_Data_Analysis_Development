# %% [markdown]
# # Worldwide data
#
# This is the same code as the WorldWideCF.ipynb notebook, but I've put it all in one cell, and it runs it for every element and generates a single Markdown file that we can then copy and paste into the required READMEs

# %% [markdown]
# ## Initial set up - import libraries and read our data

# %%
import os
import sys
from socket import gethostname

hostname = gethostname()

if hostname.startswith('hpc-node'):
    IN_DEEPTHOUGHT = True
    sys.path.append('..')
else:
    IN_DEEPTHOUGHT = False
from cf_analysis_lib.load_libraries import *
import cf_analysis_lib


# how confident are we in our predictions?
def confidence_label(prob, threshold_low=0.6, threshold_high=0.8):
    if prob < threshold_low:
        return "Low"
    elif prob < threshold_high:
        return "Medium"
    else:
        return "High"

# %% [markdown]
# # Read our data and models
#
# This is our normal models we use for predicting everything

# %%
sequence_type = "MGI"
datadir = '..'
sslevel = 'subsystems_norm_ss.tsv.gz'
taxa = "family"

our_df, our_metadata = cf_analysis_lib.read_the_data(sequence_type, datadir, all_taxa=True,
                                                     sslevel='subsystems_norm_ss.tsv.gz', taxa="family")

encoder_models = 'cluster_gbrfs_eukaryotes'
if not os.path.exists(os.path.join(encoder_models, 'clusters.json')):
    print("Please run the autoencoder code before trying to load the models.", file=sys.stderr)
    exit(1)

if not os.path.exists(os.path.join(encoder_models, 'pc_df.tsv')):
    print("Please create and save the PCA before trying to load the models.", file=sys.stderr)
    exit(1)

with open(os.path.join(encoder_models, 'clusters.json'), 'r') as file:
    data = json.load(file)
tmpjsondf = pd.DataFrame(list(data.items()), columns=['Cluster', 'Feature'])
cluster_assignments = tmpjsondf.explode('Feature').reset_index(drop=True)
cluster_assignments['Cluster'] = cluster_assignments['Cluster'].astype(int)

pc_df = pd.read_csv(os.path.join(encoder_models, 'pc_df.tsv'), sep="\t", index_col=0)
pc_df.shape
# Out:
# (127, 300)

# %% [markdown]
# # Iterate all the data sets
#
# Create a single markdown in `img/worldwide` for the whole thing.

# %%
worldwide_samples = cf_analysis_lib.worldwide_samples()
print(f"There are {len(worldwide_samples)}")

# do them all!
interesting_cluster = 56
markdown = open(os.path.join("img", "worldwide", "all_analyses2.md"), 'w')
for n, sample_id in enumerate(worldwide_samples):
    if n < 12:
        continue
    cf_analysis_lib.show_green(title="Analysis Report", message=f"Analysing: {sample_id}")
    print(f"\n================================================\n\n\n# BioProject: {sample_id}\n", file=markdown)
    os.makedirs(os.path.join("img", "worldwide", sample_id, "img"), exist_ok=True)
    print(f"Sample is {sample_id}", file=sys.stderr)
    wwdf, wwmd = cf_analysis_lib.read_worldwide_data(sample_id, verbose=True)
    # now we add any columns from our_df that are not in wwdf. This make subsequent computations easier (and correct!)
    missing = [c for c in our_df.columns if c not in wwdf.columns]
    missing_df = pd.DataFrame(0, index=wwdf.index, columns=missing)
    wwdf = pd.concat([wwdf, missing_df], axis=1).copy()
    
    print(f"We added {len(missing)} columns to ww df that were missing", file=sys.stderr)
    
    # print run counts
    run_counts = {"PRJEB14440": "- The entire data set is 5 runs, and 1,330,576,074 bp", "PRJEB20836": "- The entire data set is 1396 runs, and 1,007,979,034,098 bp", "PRJEB32062": "- The entire data set is 27 runs, and 113,773,728,053 bp", "PRJEB51171": "- The entire data set is 64 runs, and 29,874,922,519 bp", "PRJEB54014": "- The entire data set is 80 runs, and 447,488,092,200 bp", "PRJNA1055940": "- The entire data set is 61 runs, and 386,942,064,540 bp", "PRJNA1081394": "- The entire data set is 549 runs, and 510,156,291,748 bp", "PRJNA1091195": "- The entire data set is 44 runs, and 146,735,286,366 bp", "PRJNA1101448": "- The entire data set is 323 runs, and 89,493,823,284 bp", "PRJNA1126024": "- The entire data set is 2 runs, and 1,071,033,642 bp", "PRJNA316056": "- The entire data set is 12 runs, and 36,012,000,000 bp", "PRJNA316588": "- The entire data set is 18 runs, and 121,257,187,412 bp", "PRJNA510441": "- The entire data set is 14 runs, and 906,511,907 bp", "PRJNA516442": "- The entire data set is 93 runs, and 34,371,719,753 bp", "PRJNA516870": "- The entire data set is 79 runs, and 39,170,766,613 bp", "PRJNA615628": "- The entire data set is 71 runs, and 95,889,827,074 bp", "PRJNA644285": "- The entire data set is 12 runs, and 29,679,938,510 bp", "PRJNA71831": "- The entire data set is 38 runs, and 1,179,409,307 bp", "PRJNA825831": "- The entire data set is 117 runs, and 58,764,823,681 bp", "PRJNA839435": "- The entire data set is 12 runs, and 8,336,976,960 bp", "PRJNA846291": "- The entire data set is 98 runs, and 87,154,850,753 bp", "PRJNA931830": "- The entire data set is 260 runs, and 740,690,138,100 bp"}
    cf_analysis_lib.show_green(title="Analysis Report", message=f"{run_counts[sample_id]} (including amplicon sequences)")
    cf_analysis_lib.show_green(title="Analysis Report", message=f"- We analysed {len(wwdf.index)} metagenomic sequence runs.")

    print(f"{run_counts[sample_id]} (including amplicon sequences)", file=markdown)
    print(f"- We analysed {len(wwdf.index)} metagenomic sequence runs.", file=markdown)
    
    grouped = cluster_assignments.groupby("Cluster")
    
    # pc_df = pd.DataFrame(index=our_df.index, columns=[f"Cluster {x+1}" for x in range(len(cluster_assignments.groupby("Cluster").size()))])
    # ww_pc_df = pd.DataFrame(index=wwdf.index, columns=[f"Cluster {x+1}" for x in range(len(cluster_assignments.groupby("Cluster").size()))])
    fit_pca = {}
    pc_df_data = {}
    ww_pc_data = {}
    for cluster_id, group in grouped:
        df_clust = our_df[cluster_assignments.loc[cluster_assignments["Cluster"] == cluster_id, "Feature"]]
        ww_clust = wwdf[cluster_assignments.loc[cluster_assignments["Cluster"] == cluster_id, "Feature"]]
        pca = PCA(n_components=1)
        pca.fit(df_clust)
        fit_pca[cluster_id] = pca
        pc_df_data[f"Cluster {cluster_id}"] = pca.transform(df_clust)[:,0]
        ww_pc_data[f"Cluster {cluster_id}"] = pca.transform(ww_clust)[:,0]
    
    pc_df = pd.DataFrame(pc_df_data, index=our_df.index)
    ww_pc_df = pd.DataFrame(ww_pc_data, index=wwdf.index)
    
    print("Original data frames")
    print(f"Ori: min: {min(pc_df['Cluster 56']):.2f} max: {max(pc_df['Cluster 56']):.2f}")
    print(f"New: min: {min(ww_pc_df['Cluster 56']):.2f} max: {max(ww_pc_df['Cluster 56']):.2f}")
    
    # scaler = StandardScaler() # - not good because too many values at 0
    scaler = RobustScaler() 
    # scaler = MinMaxScaler() 
    
    # train the scaler on pc_df and then apply the _same scalar_ to ww_pc_df
    
    trained_scaler = scaler.fit(pc_df)
    
    pc_scaled = pd.DataFrame(
        trained_scaler.transform(pc_df),
        index=pc_df.index,
        columns=pc_df.columns
    )
    
    ww_pc_scaled = pd.DataFrame(
        trained_scaler.transform(ww_pc_df),
        index=ww_pc_df.index,
        columns=ww_pc_df.columns
    )
    print("Scaled data frames")
    print(f"Ori: min: {min(pc_scaled['Cluster 56']):.2f} max: {max(pc_scaled['Cluster 56']):.2f}")
    print(f"New: min: {min(ww_pc_scaled['Cluster 56']):.2f} max: {max(ww_pc_scaled['Cluster 56']):.2f}")
    
    intcol = 'CS_Pseudomonas aeruginosa'
    
    intcol_title = replace_index.sub('', intcol).replace('_', ' ')
    merged_df = pc_scaled.join(our_metadata[[intcol]]).dropna(subset=intcol)
    
    categorical_data, custom_labels = cf_analysis_lib.create_custom_labels(our_metadata, intcol, merged_df)
    
    X = merged_df.drop(intcol, axis=1)
    y = merged_df[intcol]
    
    if categorical_data:
      model, mse, feature_importances_sorted = cf_analysis_lib.gb_classifier_model(X, y, n_estimators=1000, n_iter_no_change=20)
      met = 'classifier'
    else:
      model, mse, feature_importances_sorted = cf_analysis_lib.gb_regressor_model(X, y)
      met = 'regressor'
    
    print(f"We used {model.n_estimators_} estimators for the random forest {met}", file=sys.stderr)
    
    predictions = model.predict(ww_pc_scaled)
    perc = predictions.sum()/len(predictions) * 100
    cf_analysis_lib.show_green(title="Analysis Report", message=f"- We predicted {predictions.sum()} samples out of {len(predictions)} ({perc:0.1f}%) have _Pseudomonas aeruginosa_")
    print(f"- We predicted {predictions.sum()} samples out of {len(predictions)} ({perc:0.1f}%) have _Pseudomonas aeruginosa_", file=markdown)
    
    probs = model.predict_proba(ww_pc_scaled)
    pred_class = np.argmax(probs, axis=1)
    pred_conf = probs[np.arange(len(probs)), pred_class]
    label_map = {0: "Negative", 1: "Positive"}
    
    # Confidence labels
    confidence = [confidence_label(p) for p in pred_conf]
    
    output = ["Sample | Pseudomonas Prediction | Confidence | Certainty\n --- | --- | --- | ---"]
    
    for i, (cls, conf, label) in enumerate(zip(pred_class, pred_conf, confidence)):
        output.append(f"{ww_pc_scaled.index[i]} | {label_map[cls]} | {conf:.2f} | {label}")
    cf_analysis_lib.show_green(title="Analysis Report", message="\n".join(output))
    print("\n\n## Prediction outcomes\n", file=markdown)
    print("\n".join(output), file=markdown)
    
    X_combined = np.vstack([pc_df, ww_pc_df])
    sample_labels = (["Adelaide"] * len(our_df)) + ([sample_id] * len(wwdf))
    group_labels = list(our_metadata[intcol]) + list(predictions)
    
    tsne = TSNE(n_components=2, perplexity=30, random_state=42)
    tsne_result = tsne.fit_transform(X_combined)
    
    df_tsne = pd.DataFrame(tsne_result, columns=["TSNE1", "TSNE2"])
    df_tsne["SampleType"] = sample_labels  # Or use group_labels
    df_tsne["Pseudomonas Predictions"] = group_labels  # Or use group_labels
    df_tsne['Pseudomonas Predictions'] = df_tsne['Pseudomonas Predictions'].map({0: 'Negative', 1: 'Positive'})
    
    # Basic comparison: New vs Original
    g = sns.scatterplot(data=df_tsne, x="TSNE1", y="TSNE2", palette='coolwarm', style="SampleType", hue="Pseudomonas Predictions")
    g.set_xlabel("t-SNE1")
    g.set_ylabel("t-SNE2")
    #plt.title(f"t-SNE of Adelaide and {sample_id} Samples")
    plt.title("")
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    
    imgout = os.path.join("img", "worldwide", sample_id, "img", f"{sample_id}_Pseudomonas_tSNE.png")
    plt.savefig(imgout)
    cf_analysis_lib.show_green(title="Analysis Report", message=f"## t-SNE\n![Comparison of Adelaide and {sample_id} samples by t-SNE](img/{sample_id}_Pseudomonas_tSNE.png 'Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted')")
    print(f"\n\n## t-SNE\n![Comparison of Adelaide and {sample_id} samples by t-SNE](img/{sample_id}_Pseudomonas_tSNE.png 'Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted')", file=markdown)
    plt.show()
    
    pca = PCA(n_components=2)
    
    intcol = 'Pseudomonas Culture'
    valid_features = [f for f in cluster_assignments.loc[cluster_assignments["Cluster"] == interesting_cluster, "Feature"] if f in wwdf.columns]
    df_clust = wwdf[valid_features]
    
    pca_result = pca.fit_transform(df_clust)
    pca_df = pd.DataFrame(data=pca_result, index=wwdf.index, columns=['PC1', 'PC2'])
    
    # Get loadings
    loadings = pca.components_.T * np.sqrt(pca.explained_variance_)
    loadings_df = pd.DataFrame(loadings, index=df_clust.columns, columns=['PC1', 'PC2'])
    
    # Create a DataFrame for top loadings
    top_loadings_df = loadings_df.loc[loadings_df['PC1'].abs().sort_values(ascending=False).index]
    top_loadings_df.head()
    
    explained_variance = pca.explained_variance_ratio_ * 100
    pc1_variance = explained_variance[0]
    pc2_variance = explained_variance[1]
    
    
    # don't forget to change the legend
    intcol_neg = 0
    colours = np.where(predictions == intcol_neg, 'blue', 'red')
    
    # Plot the PCA results
    plt.figure(figsize=(10, 8))
    plt.scatter(pca_df['PC1'], pca_df['PC2'], c=colours, alpha=0.2)
    #plt.title(f"PCA of the 'Pseudomonas' cluster (#56) in {sample_id}")
    plt.title("")
    plt.xlabel(f'Principal Component 1 ({pc1_variance:.3f}%)')
    plt.ylabel(f'Principal Component 2 ({pc2_variance:.3f}%)')
    
    # add the loadings ... we only plot maxloadings here
    maxloadings = 5
    if len(loadings) < maxloadings:
        maxloadings = len(loadings)
    
    plotscaler = 2
    texts = []
    colour_cycle = cycle(mcolors.TABLEAU_COLORS)
    found_pseudomonas = False
    for i in range(maxloadings):
        c = next(colour_cycle)
        xpos = top_loadings_df.iloc[i, 0]*plotscaler
        ypos = top_loadings_df.iloc[i, 1]*plotscaler
        plt.arrow(0, 0, xpos, ypos, 
                  color=c, alpha=0.5, width=0.05)
        texts.append(plt.text(xpos, ypos, top_loadings_df.index[i], color=c))
    
    adjust_text(texts)
    
    
    # Add a legend
    blue_patch = plt.Line2D([0], [0], marker='o', color='w', label='Predicted Pseudomonas positive', 
                             markerfacecolor='red', alpha=0.2, markersize=10)
    red_patch = plt.Line2D([0], [0], marker='o', color='w', label='Predictied Pseudomonas negative', 
                            markerfacecolor='blue', alpha=0.2, markersize=10)
    
    
    plt.legend(handles=[blue_patch, red_patch])
    
    imgout = os.path.join("img", "worldwide", sample_id, "img", f"{sample_id}_Pseudomonas_PCA.png")
    plt.savefig(imgout)
    cf_analysis_lib.show_green(title="Analysis Report", message=f"## PCA\n![This cluster of features are most strongly associated with the presence of Pseudomonas](img/{sample_id}_Pseudomonas_PCA.png 'Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in {sample_id}')")
    print(f"\n\n## PCA\n![This cluster of features are most strongly associated with the presence of Pseudomonas](img/{sample_id}_Pseudomonas_PCA.png 'Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in {sample_id}')", file=markdown)
    # Show the plot
    plt.show()

markdown.close()
# Out:
# There are 24
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA1101448</div></div>
# Sample is PRJNA1101448
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA1101448/subsystems/PRJNA1101448_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (792, 323) and after is (792, 323)
# Read 323 samples and 792 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA1101448/taxonomy_summary/PRJNA1101448_family.norm.tsv.gz
# Read 323 samples and 2879 family
# Read 323 samples and 7 metadata columns
# We added 57 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 323 runs, and 89,493,823,284 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 323 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -22351.21 max: 247264.36
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.66 max: 61.17
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 0 samples out of 323 (0.0%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR28721064 | Negative | 0.75 | Medium<br>SRR28721065 | Negative | 0.77 | Medium<br>SRR28721066 | Negative | 0.85 | High<br>SRR28721067 | Negative | 0.80 | High<br>SRR28721068 | Negative | 0.74 | Medium<br>SRR28721069 | Negative | 0.84 | High<br>SRR28721070 | Negative | 0.79 | Medium<br>SRR28721071 | Negative | 0.82 | High<br>SRR28721072 | Negative | 0.75 | Medium<br>SRR28721073 | Negative | 0.86 | High<br>SRR28721074 | Negative | 0.79 | Medium<br>SRR28721075 | Negative | 0.79 | Medium<br>SRR28721076 | Negative | 0.75 | Medium<br>SRR28721077 | Negative | 0.77 | Medium<br>SRR28721078 | Negative | 0.79 | Medium<br>SRR28721079 | Negative | 0.74 | Medium<br>SRR28721080 | Negative | 0.76 | Medium<br>SRR28721081 | Negative | 0.74 | Medium<br>SRR28721082 | Negative | 0.82 | High<br>SRR28
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA1101448 samples by t-SNE](img/PRJNA1101448_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA1101448_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA1101448&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA316056</div></div>
# Sample is PRJNA316056
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA316056/subsystems/PRJNA316056_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (665, 12) and after is (665, 12)
# Read 12 samples and 665 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA316056/taxonomy_summary/PRJNA316056_family.norm.tsv.gz
# Read 12 samples and 999 family
# Read 12 samples and 7 metadata columns
# We added 1058 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 12 runs, and 36,012,000,000 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 12 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -21573.03 max: 434785.33
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.48 max: 104.17
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 6 samples out of 12 (50.0%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR3284697 | Negative | 0.80 | Medium<br>SRR3284698 | Positive | 0.62 | Medium<br>SRR3284701 | Negative | 0.79 | Medium<br>SRR3284702 | Negative | 0.73 | Medium<br>SRR3284703 | Positive | 0.66 | Medium<br>SRR3284706 | Positive | 0.68 | Medium<br>SRR3286490 | Positive | 0.52 | Low<br>SRR3286491 | Negative | 0.69 | Medium<br>SRR3286492 | Negative | 0.91 | High<br>SRR3286493 | Positive | 0.63 | Medium<br>SRR3286494 | Negative | 0.70 | Medium<br>SRR3286495 | Positive | 0.75 | Medium</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA316056 samples by t-SNE](img/PRJNA316056_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA316056_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA316056&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA316588</div></div>
# Sample is PRJNA316588
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA316588/subsystems/PRJNA316588_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (703, 18) and after is (703, 17)
# Read 17 samples and 703 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA316588/taxonomy_summary/PRJNA316588_family.norm.tsv.gz
# Read 18 samples and 1846 family
# Read 18 samples and 7 metadata columns
# We added 364 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 18 runs, and 121,257,187,412 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 17 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -22191.73 max: 440837.52
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.62 max: 105.56
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 2 samples out of 17 (11.8%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR5109913 | Negative | 0.65 | Medium<br>SRR5109957 | Positive | 0.67 | Medium<br>SRR5109959 | Positive | 0.63 | Medium<br>SRR5109960 | Negative | 0.84 | High<br>SRR5109961 | Negative | 0.71 | Medium<br>SRR5110005 | Negative | 0.81 | High<br>SRR5110496 | Negative | 0.79 | Medium<br>SRR5110508 | Negative | 0.86 | High<br>SRR5110517 | Negative | 0.85 | High<br>SRR5110523 | Negative | 0.78 | Medium<br>SRR5110531 | Negative | 0.69 | Medium<br>SRR5110535 | Negative | 0.68 | Medium<br>SRR5110576 | Negative | 0.76 | Medium<br>SRR5110588 | Negative | 0.74 | Medium<br>SRR5110763 | Negative | 0.86 | High<br>SRR5110777 | Negative | 0.77 | Medium<br>SRR5110789 | Negative | 0.70 | Medium</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA316588 samples by t-SNE](img/PRJNA316588_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA316588_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA316588&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA510441</div></div>
# Sample is PRJNA510441
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA510441/subsystems/PRJNA510441_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (615, 14) and after is (615, 14)
# Read 14 samples and 615 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA510441/taxonomy_summary/PRJNA510441_family.norm.tsv.gz
# Read 14 samples and 808 family
# Read 14 samples and 7 metadata columns
# We added 1288 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 14 runs, and 906,511,907 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 14 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: 8644.41 max: 421939.17
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: 6.45 max: 101.23
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 5 samples out of 14 (35.7%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR8334087 | Negative | 0.69 | Medium<br>SRR8334088 | Negative | 0.50 | Low<br>SRR8334089 | Positive | 0.67 | Medium<br>SRR8334090 | Positive | 0.70 | Medium<br>SRR8334091 | Negative | 0.69 | Medium<br>SRR8334092 | Negative | 0.57 | Low<br>SRR8334093 | Positive | 0.66 | Medium<br>SRR8334094 | Negative | 0.60 | Low<br>SRR8334095 | Negative | 0.63 | Medium<br>SRR8334096 | Negative | 0.62 | Medium<br>SRR8334097 | Negative | 0.53 | Low<br>SRR8334098 | Negative | 0.51 | Low<br>SRR8334099 | Positive | 0.57 | Low<br>SRR8334100 | Positive | 0.62 | Medium</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA510441 samples by t-SNE](img/PRJNA510441_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA510441_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA510441&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA615628</div></div>
# Sample is PRJNA615628
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA615628/subsystems/PRJNA615628_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (756, 71) and after is (756, 71)
# Read 71 samples and 756 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA615628/taxonomy_summary/PRJNA615628_family.norm.tsv.gz
# Read 71 samples and 2124 family
# Read 71 samples and 7 metadata columns
# We added 184 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 71 runs, and 95,889,827,074 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 71 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -22348.02 max: 421060.97
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.66 max: 101.03
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 2 samples out of 71 (2.8%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR11440759 | Negative | 0.72 | Medium<br>SRR11440760 | Negative | 0.83 | High<br>SRR11440761 | Negative | 0.73 | Medium<br>SRR11440762 | Negative | 0.75 | Medium<br>SRR11440763 | Negative | 0.85 | High<br>SRR11440764 | Negative | 0.78 | Medium<br>SRR11440765 | Negative | 0.83 | High<br>SRR11440766 | Negative | 0.87 | High<br>SRR11440767 | Negative | 0.85 | High<br>SRR11440768 | Negative | 0.87 | High<br>SRR11440769 | Negative | 0.85 | High<br>SRR11440770 | Negative | 0.85 | High<br>SRR11440771 | Negative | 0.80 | High<br>SRR11440772 | Negative | 0.84 | High<br>SRR11440773 | Negative | 0.73 | Medium<br>SRR11440774 | Negative | 0.86 | High<br>SRR11440775 | Negative | 0.86 | High<br>SRR11440776 | Negative | 0.72 | Medium<br>SRR11440777 | Neg
div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA644285</div></div>
# Sample is PRJNA644285
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA644285/subsystems/PRJNA644285_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (666, 12) and after is (666, 12)
# Read 12 samples and 666 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA644285/taxonomy_summary/PRJNA644285_family.norm.tsv.gz
# Read 12 samples and 1138 family
# Read 12 samples and 7 metadata columns
# We added 936 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 12 runs, and 29,679,938,510 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 12 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -20725.51 max: 74279.53
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.29 max: 21.50
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 3 samples out of 12 (25.0%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR12149829 | Negative | 0.69 | Medium<br>SRR12149830 | Negative | 0.64 | Medium<br>SRR12149831 | Positive | 0.66 | Medium<br>SRR12149832 | Negative | 0.53 | Low<br>SRR12149833 | Positive | 0.59 | Low<br>SRR12149834 | Negative | 0.71 | Medium<br>SRR12149835 | Negative | 0.67 | Medium<br>SRR12149836 | Negative | 0.72 | Medium<br>SRR12149837 | Negative | 0.71 | Medium<br>SRR12149838 | Negative | 0.56 | Low<br>SRR12149839 | Negative | 0.65 | Medium<br>SRR12149840 | Positive | 0.59 | Low</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA644285 samples by t-SNE](img/PRJNA644285_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA644285_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA644285&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA825831</div></div>
# Sample is PRJNA825831
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA825831/subsystems/PRJNA825831_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (755, 114) and after is (755, 114)
# Read 114 samples and 755 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA825831/taxonomy_summary/PRJNA825831_family.norm.tsv.gz
# Read 114 samples and 2296 family
# Read 117 samples and 7 metadata columns
# We added 131 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 117 runs, and 58,764,823,681 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 114 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -22429.07 max: 437214.57
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.68 max: 104.73
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 12 samples out of 114 (10.5%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div
>SRR19051601 | Negative | 0.70 | Medium<br>SRR19051602 | Negative | 0.70 | Medium<br>SRR19051603 | Positive | 0.72 | Medium<br>SRR19051604 | Negative | 0.63 | Medium<br>SRR19051605 | Negative | 0.74 | Medium<br>SRR19051606 | Negative | 0.78 | Medium<br>SRR19051607 | Negative | 0.77 | Medium<br>SRR19051608 | Negative | 0.80 | High<br>SRR19051609 | Negative | 0.73 | Medium<br>SRR19051610 | Negative | 0.79 | Medium<br>SRR19051611 | Negative | 0.80 | Medium<br>SRR19051612 | Negative | 0.60 | Low<br>SRR19051613 | Negative | 0.58 | Low<br>SRR19051614 | Negative | 0.77 | Medium<br>SRR19051615 | Negative | 0.78 | Medium<br>SRR19051616 | Negative | 0.76 | Medium<br>SRR19051617 | Negative | 0.89 | High<br>SRR19051618 | Negative | 0.86 | High<br>SRR19051619 | Positive | 0.65 | Medium<br>SRR19051620 | Negative | 0.53 | Low<br>SRR19051621 | Negative | 0.51 | Low<br> ...
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA825831 samples by t-SNE](img/PRJNA825831_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA825831_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA825831&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA839435</div></div>
# Sample is PRJNA839435
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA839435/subsystems/PRJNA839435_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (660, 12) and after is (660, 12)
# Read 12 samples and 660 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA839435/taxonomy_summary/PRJNA839435_family.norm.tsv.gz
# Read 12 samples and 1075 family
# Read 12 samples and 7 metadata columns
# We added 993 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 12 runs, and 8,336,976,960 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 12 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: 12963.34 max: 435964.76
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: 7.44 max: 104.44
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 11 samples out of 12 (91.7%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR19277164 | Positive | 0.71 | Medium<br>SRR19277165 | Positive | 0.72 | Medium<br>SRR19277166 | Positive | 0.66 | Medium<br>SRR19277167 | Positive | 0.74 | Medium<br>SRR19277168 | Positive | 0.64 | Medium<br>SRR19277169 | Positive | 0.75 | Medium<br>SRR19277170 | Negative | 0.76 | Medium<br>SRR19277171 | Positive | 0.78 | Medium<br>SRR19277172 | Positive | 0.73 | Medium<br>SRR19277173 | Positive | 0.52 | Low<br>SRR19277174 | Positive | 0.65 | Medium<br>SRR19277175 | Positive | 0.68 | Medium</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA839435 samples by t-SNE](img/PRJNA839435_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA839435_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA839435&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA846291</div></div>
# Sample is PRJNA846291
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA846291/subsystems/PRJNA846291_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (748, 98) and after is (748, 98)
# Read 98 samples and 748 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA846291/taxonomy_summary/PRJNA846291_family.norm.tsv.gz
# Read 98 samples and 2222 family
# Read 98 samples and 7 metadata columns
# We added 159 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 98 runs, and 87,154,850,753 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 98 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -22324.55 max: 165628.92
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.65 max: 42.45
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 1 samples out of 98 (1.0%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR19579576 | Negative | 0.77 | Medium<br>SRR19579577 | Negative | 0.77 | Medium<br>SRR19579578 | Negative | 0.76 | Medium<br>SRR19579579 | Negative | 0.72 | Medium<br>SRR19579580 | Negative | 0.76 | Medium<br>SRR19579581 | Negative | 0.77 | Medium<br>SRR19579582 | Negative | 0.83 | High<br>SRR19579583 | Negative | 0.84 | High<br>SRR19579584 | Negative | 0.82 | High<br>SRR19579585 | Negative | 0.84 | High<br>SRR19579586 | Negative | 0.83 | High<br>SRR19579587 | Negative | 0.78 | Medium<br>SRR19579588 | Negative | 0.57 | Low<br>SRR19579589 | Negative | 0.72 | Medium<br>SRR19579590 | Negative | 0.73 | Medium<br>SRR19579591 | Negative | 0.80 | Medium<br>SRR19579592 | Negative | 0.80 | Medium<br>SRR19579593 | Negative | 0.75 | Medium<br>SRR19579594 | Positive | 0.50 | Low<br>SRR19579595 | Negative | 0.60 | Low<br>SRR19579596 | Negative | 0.83 | High<br>SRR19579597 | Negative | 0.81 | High<br>SRR19579598 | Negative | 0.84 | High<br>SRR19579599 | Negative | 0.80 | Medium<br>SRR19579600 | Negative | 0.79 | Medium<br>SRR19579601 | Negative | 0.84 | High<br>SRR19579602 | Negative | 0.51 | Low<br>SRR19579603 | Negative | 0.67 | Medium<br>SRR19579604 | Negative | 0.77 | Medium<br>SRR19579605 | Negative | 0.81 | High<br>SRR19579606 | Negative | 0.75 | Medium<br>SRR19579607 | Negative | 0.68
div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: PRJNA931830</div></div>
# Sample is PRJNA931830
# Reading subsystems from ../WorldWideDataAnalysis/Atavide/PRJNA931830/subsystems/PRJNA931830_subsystems_norm_ss.tsv.gz
# Before dropping suspects, shape is (798, 260) and after is (798, 260)
# Read 260 samples and 798 subsystems
# Reading taxonomy from ../WorldWideDataAnalysis/Atavide/PRJNA931830/taxonomy_summary/PRJNA931830_family.norm.tsv.gz
# Read 260 samples and 2680 family
# Read 260 samples and 7 metadata columns
# We added 62 columns to ww df that were missing
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- The entire data set is 260 runs, and 740,690,138,100 bp (including amplicon sequences)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We analysed 260 metagenomic sequence runs.</div></div>
# Original data frames
# Ori: min: -22023.06 max: 481754.57
# New: min: -22230.31 max: 446706.53
# Scaled data frames
# Ori: min: -0.58 max: 114.95
# New: min: -0.63 max: 106.91
# WARNING: Early stopping after only 441 estimators were built to avoid overfitting
# We used 441 estimators for the random forest classifier
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>- We predicted 12 samples out of 260 (4.6%) have _Pseudomonas aeruginosa_</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Sample | Pseudomonas Prediction | Confidence | Certainty<br> --- | --- | --- | ---<br>SRR23346028 | Negative | 0.79 | Medium<br>SRR23346029 | Negative | 0.67 | Medium<br>SRR23346030 | Negative | 0.74 | Medium<br>SRR23346031 | Negative | 0.82 | High<br>SRR23346032 | Negative | 0.80 | High<br>SRR23346033 | Negative | 0.80 | High<br>SRR23346034 | Negative | 0.62 | Medium<br>SRR23346035 | Negative | 0.70 | Medium<br>SRR23346036 | Negative | 0.74 | Medium<br>SRR23346037 | Negative | 0.76 | Medium<br>SRR23346038 | Negative | 0.65 | Medium<br>SRR23346039 | Negative | 0.80 | High<br>SRR23346040 | Negative | 0.68 | Medium<br>SRR23346041 | Negative | 0.64 | Medium<br>SRR23346042 | Negative | 0.90 | High<br>SRR23346043 | Negative | 0.75 | Medium<br>SRR23346044 | Negative | 0.78 | Medium<br>SRR23346045 | Positive | 0.51 | Low<br>SRR23346046 | Negative | 0.73 | Medium<br>SRR23346047 | Negative | 0.73 | Medium<br>SRR23346048 | Negative | 0.73 | Medium<br>SRR23346049 | Negative | 0.70 | Medium<br>SRR23346050 | Positive | 0.66 | Medium<br>SRR23346051 | Negative | 0.76 | Medium<br>SRR23346052 | Negative | 0.79 | Medium<br>SRR23346053 | Negative | 0.81 | High<br>SRR23346054 | Positive | 0.64 | Medium<br>SRR23346055 | Negative | 0.76 | Medium<br>SRR23346056 | Negative | 0.71 | Medium<br>SRR23346057 | Negative | 0.69 | Medium<br>SRR23346058 | Negative | 0.66 | Medium<br>SRR23346059 | Negative | 0.79 | Medium<br>SRR23346060 | Negative | 0.75 | Medium<br>SRR23346061 | Negative | 0.71 | Medium<br>SRR23346062 | Negative | 0.72 | Medium<br>SRR23346063 | Negative | 0.77 | Medium<br>SRR23346064 | Negative | 0.81 | High<br>SRR23346065 | Negative | 0.75 | Medium<br>SRR23346066 | Negative | 0.67 | Medium<br>SRR23346067 | Negative | 0.79 | Medium<br>SRR23346068 | Negative | 0.81 | High<br>SRR23346069 | Negative | 0.76 | Medium<br>SRR23346070 | Negative | 0.75 | Medium<br>SRR23346071 | Negative | 0.83 | High<br>SRR23346072 | Negative | 0.64 | Medium<br>SRR23346073 | Negative | 0.77 | Medium<br>SRR23346074 | Negative | 0.67 | Medium<br>SRR23346075 | Negative | 0.76 | Medium<br>SRR23346076 | Negative | 0.58 | Low<br>SRR23346077 | Negative | 0.68 | Medium<br>SRR23346078 | Negative | 0.77 | Medium<br>SRR23346079 | Negative | 0.70 | Medium<br>SRR23346080 | Negative | 0.76 | Medium<br>SRR23346081 | Negative | 0.76 | Medium<br>SRR23346082 | Negative | 0.74 | Medium<br>SRR23346083 | Negative | 0.61 | Medium<br>SRR23346084 | Negative | 0.57 | Low<br>SRR23346085 | Negative | 0.78 | Medium<br>SRR23346086 | Negative | 0.80 | Medium<br>SRR23346087 | Negative | 0.73 | Medium<br>SRR23346088 | Negative | 0.81 | High<br>SRR23346089 | Negative | 0.74 | Medium<br>SRR23346090 | Negative | 0.69 | Medium<br>SRR23346091 | Negative | 0.56 | Low<br>SRR23346092 | Negative | 0.80 | Medium<br>SRR23346093 | Negative | 0.81 | High<br>SRR23346094 | Negative | 0.80 | Medium<br>SRR23346095 | Positive | 0.71 | Medium<br>SRR23346096 | Negative | 0.65 | Medium<br>SRR23346097 | Negative | 0.68 | Medium<br>SRR23346098 | Negative | 0.78 | Medium<br>SRR23346099 | Negative | 0.74 | Medium<br>SRR23346100 | Positive | 0.68 | Medium<br>SRR23346101 | Negative | 0.71 | Medium<br>SRR23346102 | Negative | 0.82 | High<br>SRR23346103 | Negative | 0.67 | Medium<br>SRR23346104 | Negative | 0.77 | Medium<br>SRR23346105 | Negative | 0.62 | Medium<br>SRR23346106 | Positive | 0.56 | Low<br>SRR23346107 | Negative | 0.59 | Low<br>SRR23346108 | Negative | 0.68 | Medium<br>SRR23346109 | Negative | 0.69 | Medium<br>SRR23346110 | Negative | 0.56 | Low<br>SRR23346111 | Negative | 0.80 | High<br>SRR23346112 | Negative | 0.79 | Medium<br>SRR23346113 | Negative | 0.80 | Medium<br>SRR23346114 | Negative | 0.64 | Medium<br>SRR233 ...
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## t-SNE<br>![Comparison of Adelaide and PRJNA931830 samples by t-SNE](img/PRJNA931830_Pseudomonas_tSNE.png &#x27;Fig. t-SNE of all the analysed sequence data coloured by whether Pseudomonas is predicted&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>## PCA<br>![This cluster of features are most strongly associated with the presence of Pseudomonas](img/PRJNA931830_Pseudomonas_PCA.png &#x27;Fig. PCA of the cluster of features most strongly associated with Pseudomonas colonization in PRJNA931830&#x27;)</div></div>
# <div style="background-color:#d4edda;border:1px solid #155724;color:#155724;padding:10px 12px;border-radius:8px;font-family:system-ui,-apple-system,Segoe UI,Roboto,Helvetica,Arial,sans-serif;line-height:1.4;max-width:none;"><div style="font-weight:600; margin-bottom:4px;">✅ Analysis Report</div><div>Analysing: not_analysed</div></div>
# Sample is not_analysed
# Error: ../WorldWideDataAnalysis/Atavide/not_analysed/subsystems/not_analysed_subsystems_norm_ss.tsv.gz does not exist
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# /home/edwa0468/miniconda3/envs/bioinformatics/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
