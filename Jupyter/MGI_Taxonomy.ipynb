# %% [markdown]
# # MGI Taxonomy Data
#
# This is the same format in both MinION and MGI data, so we can use these data frames interoperably.

# %%
import os
import sys

import re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
import pandas as pd
import seaborn as sns
import json

# %% [markdown]
# ## Read the data
#
# We read the data, and limit only to Bacteria. We analyse the viruses separately, and we choose to eliminate the Archaea and Eukarya since they are very minor components of the data. We also log the data.

# %%
df = pd.read_csv("../MGI/Taxonomy/MGI_reads_genus.normalised.tsv.gz", sep='\t', compression='gzip')
df = df[df['taxonomy'].str.contains('k__Bacteria')]
df = df[~df['taxonomy'].str.endswith('g__')]
df = df.set_index('taxonomy')

epsilon = 1e-10
log_df = np.log(df + epsilon)/np.log(10)
df['row sum'] = df.sum(axis=1)
log_df['row sum'] = log_df.sum(axis=1)
log_df['row sum'].sort_values(ascending=False)
# Out:
# taxonomy
# k__Bacteria;p__Bacillota;c__Bacilli;o__Lactobacillales;f__Streptococcaceae;g__Streptococcus                           662.242658
# k__Bacteria;p__Actinomycetota;c__Actinomycetes;o__Micrococcales;f__Micrococcaceae;g__Rothia                           605.184482
# k__Bacteria;p__Bacteroidota;c__Bacteroidia;o__Bacteroidales;f__Prevotellaceae;g__Prevotella                           524.699243
# k__Bacteria;p__Actinomycetota;c__Actinomycetes;o__Actinomycetales;f__Actinomycetaceae;g__Actinomyces                  522.419482
# k__Bacteria;p__Bacillota;c__Negativicutes;o__Veillonellales;f__Veillonellaceae;g__Veillonella                         468.660301
#                                                                                                                         ...
# k__Bacteria;p__Thermodesulfobacteriota;c__Desulfuromonadia;o__Geobacterales;f__Geobacteraceae;g__Geomobilimonas     -1260.787509
# k__Bacteria;p__Pseudomonadota;c__Alphaproteobacteria;o__Sphingomonadales;f__Erythrobacteraceae;g__Croceibacterium   -1260.806471
# k__Bacteria;p__Pseudomonadota;c__Alphaproteobacteria;o__Rhodobacterales;f__Roseobacteraceae;g__Poseidonocella       -1260.827614
# k__Bacteria;p__Pseudomonadota;c__Betaproteobacteria;o__Burkholderiales;f__Comamonadaceae;g__Oryzisolibacter         -1260.827614
# k__Bacteria;p__Deinococcota;c__Deinococci;o__Thermales;f__Thermaceae;g__Marinithermus                               -1260.830781
# Name: row sum, Length: 3581, dtype: float64

# %% [markdown]
# ## KDE
#
# Plot a kde of the log data so we know approximately where to set the cutoff.

# %%
g = sns.kdeplot(log_df['row sum'], bw_adjust=0.5)

# %% [markdown]
# Here, we filter the log-normalised data so that the row sums are >0 (ie. there are 10 or more normalised reads in the row sum). We also sort by the index and the columns.

# %%
log_df = log_df[log_df['row sum'] > 350]
log_df.index = log_df.index.str.replace('g__', '').str.split(';').str[-1]

# sort by the index
log_df = log_df.sort_index()
# sort by the column labels
log_df = log_df.sort_index(axis=1)

# %% [markdown]
# ### plot the data
#
# This heat map summarises the abundance per sample

# %%
fig, ax = plt.subplots(figsize=(18, 12))
g = sns.heatmap(data=log_df.iloc[:, :-1], ax=ax, cmap="rocket_r")
g.set_xlabel("")
g.set_ylabel("")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.savefig('minion_taxonomy_heatmap.png')
