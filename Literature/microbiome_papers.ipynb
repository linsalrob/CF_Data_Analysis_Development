# %% [markdown]
# # Literature analysis
#
# Rob Manually curated a bunch of the literature (~750 papers) in an excel file that is primarily in the CF Manuscripts folder. Here we plot the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.listdir()
# Out:
# ['CF Microbiome and Metagenome Papers Annotated.txt',
#  'SamplesPerPublication.png',
#  'microbiome_papers.ipynb',
#  '.ipynb_checkpoints']

# %%
df = pd.read_csv('CF Microbiome and Metagenome Papers Annotated.txt', sep="\t")
df
# Out:
#          PMID         Sample Type  \
# 0    37598041           fecal 16S
# 1    31992345           fecal 16S
# 2    37607068           fecal 16S
# 3    35764510           fecal 16S
# 4    36717332           fecal 16S
# ..        ...                 ...
# 990  19047519  microbial genomics
# 991  18287045  microbial genomics
# 992  29967020  microbial genomics
# 993  36625656      human genomics
# 994  33958799      human genomics
#
#                                                Journal  \
# 0    Journal of cystic fibrosis : official journal ...
# 1                                      Genome medicine
# 2                                Microbiology spectrum
# 3    Journal of cystic fibrosis : official journal ...
# 4    Journal of cystic fibrosis : official journal ...
# ..                                                 ...
# 990                                    Genome research
# 991  Proceedings of the National Academy of Science...
# 992              Antimicrobial agents and chemotherapy
# 993                                               mBio
# 994                                    Nature medicine
#
#                                          Article Title  \
# 0    The association between gut microbiome and gro...
# 1    Interactions between the gut microbiome and ho...
# 2    Tezacaftor/Ivacaftor therapy has negligible ef...
# 3    Modulation, microbiota and inflammation in the...
# 4    The gut microbiome, short chain fatty acids, a...
# ..                                                 ...
# 990  Newly introduced genomic prophage islands are ...
# 991  Dynamics of Pseudomonas aeruginosa genome evol...
# 992  Broad-Spectrum Adaptive Antibiotic Resistance ...
# 993  SARS-CoV-2-Mediated Lung Edema and Replication...
# 994  Transcriptional analysis of cystic fibrosis ai...
#
#                                               Abstract  \
# 0    In cystic fibrosis (CF), pathophysiologic chan...
# 1    Cystic fibrosis is the most common autosomal r...
# 2    People with cystic fibrosis (pwCF) experience ...
# 3    Cystic Fibrosis (CF) has prominent gastrointes...
# 4    Adults with cystic fibrosis (CF) are at increa...
# ..                                                 ...
# 990  Pseudomonas aeruginosa isolates have a highly ...
# 991  One of the hallmarks of the Gram-negative bact...
# 992  Surfing motility is a novel form of surface ad...
# 993  Coronaviruses (CoVs) of genera α, β, γ, and δ ...
# 994  Cystic fibrosis (CF) is a lethal autosomal rec...
#
#     Number of samples/patients
# 0                           78
# 1                            ?
# 2                           12
# 3                           14
# 4                           42
# ..                         ...
# 990                        NaN
# 991                        NaN
# 992                        NaN
# 993                        NaN
# 994                        NaN
#
# [995 rows x 6 columns]

# %%
df = df.dropna(axis=0)

# %%
df = df[df['Number of samples/patients'] != "?"]

# %%
df['num'] = df['Number of samples/patients'].astype(float)

# %%
df[df['Sample Type'] == 'fecal 16S'].max()
# Out:
# PMID                                                                   38960841
# Sample Type                                                           fecal 16S
# Journal                                                      Scientific reports
# Article Title                 The relationship between the intestinal microb...
# Abstract                      There is a paucity of knowledge on the longer-...
# Number of samples/patients                                                   78
# num                                                                       173.0
# dtype: object

# %%
figsize = (12, 1.2 * len(df['Sample Type'].unique()))
plt.figure(figsize=figsize)
ax = sns.violinplot(data=df, x='Sample Type', y='num', hue='Sample Type', inner=None, palette='Dark2', dodge=False)
sns.stripplot(data=df, x='Sample Type', y='num', jitter=True, color='k', alpha=0.6)
sns.despine(top=True, right=True, bottom=False, left=False)
plt.show()

# %%
selected = df[(df['Sample Type'] == 'sputum 16S') | (df['Sample Type'] == 'metagenomics') | (df['Sample Type'] == 'viromics') | (df['Sample Type'] == 'metagenomics and 16S')]
selected.loc[selected['Sample Type'] == 'sputum 16S', 'Sample Type'] = '16S'
selected.loc[selected['Sample Type'] == 'metagenomics', 'Sample Type'] = 'Metagenomics'
selected.loc[selected['Sample Type'] == 'metagenomics and 16S', 'Sample Type'] = 'Metagenomics'
selected.loc[selected['Sample Type'] == 'viromics', 'Sample Type'] = 'Viromics'
selected
# Out:
#          PMID   Sample Type  \
# 30   37474497  Metagenomics
# 32   38762736  Metagenomics
# 34   36748565  Metagenomics
# 35   22951208  Metagenomics
# 36   28187782  Metagenomics
# ..        ...           ...
# 216  21178461      Viromics
# 217  25741327      Viromics
# 219  32442222      Viromics
# 736  38702223  Metagenomics
# 976  22355331      Viromics
#
#                                                Journal  \
# 30                               Nature communications
# 32                                Respiratory research
# 34                     Journal of medical microbiology
# 35   Journal of cystic fibrosis : official journal ...
# 36                                          Microbiome
# ..                                                 ...
# 216                                          Virulence
# 217                          Frontiers in microbiology
# 219                                           PloS one
# 736  Journal of cystic fibrosis : official journal ...
# 976                                           PloS one
#
#                                          Article Title  \
# 30   Genome-scale metabolic modeling of Aspergillus...
# 32   Comparative microbiome analysis in cystic fibr...
# 34   Meta-analysis of sputum microbiome studies ide...
# 35   Metagenomics and metatranscriptomics: windows ...
# 36   Sputum DNA sequencing in cystic fibrosis: non-...
# ..                                                 ...
# 216  Deciphering the role of phage in the cystic fi...
# 217  A metagenomic approach to characterize tempera...
# 219  The intestinal virome in children with cystic ...
# 736  Widespread alterations in systemic immune prof...
# 976  Characterization of the viral microbiome in pa...
#
#                                               Abstract  \
# 30   Aspergillus fumigatus, an opportunistic human ...
# 32   Bronchiectasis is a condition characterized by...
# 34   Studying taxonomic and functional signatures o...
# 35   Samples collected from CF patient airways ofte...
# 36   Cystic fibrosis (CF) is a life-threatening gen...
# ..                                                 ...
# 216  Cystic fibrosis (CF) is a fatal genetic disord...
# 217  Pseudomonas aeruginosa (Pa), normally a soil c...
# 219  Intestinal bacterial dysbiosis is evident in c...
# 736  Excessive inflammation and recurrent airway in...
# 976  The human respiratory tract is heavily exposed...
#
#     Number of samples/patients    num
# 30                          40   40.0
# 32                          35   35.0
# 34                          57   57.0
# 35                           5    5.0
# 36                           6    6.0
# ..                         ...    ...
# 216                          6    6.0
# 217                         92   92.0
# 219                          8    8.0
# 736                         28   28.0
# 976                        210  210.0
#
# [155 rows x 7 columns]

# %%
figsize = (12, 1.2 * len(df['Sample Type'].unique()))
plt.figure(figsize=figsize)
order = ['16S', 'Metagenomics', 'Viromics']
ax = sns.violinplot(data=selected, x='Sample Type', y='num', hue='Sample Type', inner=None, palette='Dark2', dodge=False, width=0.5, order=order)
sns.stripplot(data=selected, x='Sample Type', y='num', jitter=0.2, color='k', alpha=0.6, order=order)
sns.despine(top=True, right=True, bottom=False, left=False)
plt.xlabel("Sputum sequencing from pwCF")
plt.ylabel("Number of samples per study")
plt.legend().remove()
plt.tight_layout()
plt.show()
plt.savefig('SamplesPerPublication.png')
plt.savefig('SamplesPerPublication.svg')
# Out:
# /local/edwa0468/2669710/ipykernel_2352335/3085852662.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend().remove()

# %%
selected.groupby(['Sample Type'])['num'].mean()
# Out:
# Sample Type
# 16S             108.221374
# Metagenomics     31.941176
# Viromics         55.285714
# Name: num, dtype: float64

# %%
selected.groupby(['Sample Type'])['num'].median()
# Out:
# Sample Type
# 16S             37.0
# Metagenomics    28.0
# Viromics         8.0
# Name: num, dtype: float64

# %%
selected.groupby(['Sample Type'])['num'].max()
# Out:
# Sample Type
# 16S             880.0
# Metagenomics     82.0
# Viromics        210.0
# Name: num, dtype: float64

# %%
selected.groupby(['Sample Type'])['num'].count()
# Out:
# Sample Type
# 16S             131
# Metagenomics     17
# Viromics          7
# Name: num, dtype: int64

# %%
selected[(selected['Sample Type'] == '16S') & (selected['num'] > 800)]
# Out:
#          PMID Sample Type                                            Journal  \
# 64   38261629         16S  American journal of respiratory and critical c...
# 94   34689185         16S                                   The ISME journal
# 158  27180018         16S                   The Lancet. Respiratory medicine
# 177  37546739         16S          bioRxiv : the preprint server for biology
#
#                                          Article Title  \
# 64   Loss of Airway Phylogenetic Diversity Is Assoc...
# 94   Association of bacterial community types, func...
# 158  The nasal microbiota in infants with cystic fi...
# 177  Microbial community organization designates di...
#
#                                               Abstract  \
# 64   The airway microbiome has the potential to sha...
# 94   Bacterial infection and inflammation of the ai...
# 158  Respiratory tract infections and subsequent ai...
# 177  Polymicrobial infection of the airways is a ha...
#
#     Number of samples/patients    num
# 64                         877  877.0
# 94                         818  818.0
# 158                        872  872.0
# 177                        880  880.0

# %%
selected[(selected['Sample Type'] == 'Metagenomics') & (selected['num'] > 80)]
# Out:
#         PMID   Sample Type                                            Journal  \
# 47  32580896  Metagenomics  The Journal of heart and lung transplantation ...
#
#                                         Article Title  \
# 47  Pediatric lung transplantation: Dynamics of th...
#
#                                              Abstract  \
# 47  Compositional changes in the microbiome are as...
#
#    Number of samples/patients   num
# 47                         82  82.0
